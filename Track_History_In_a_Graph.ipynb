# %% [markdown]
# <a href="https://colab.research.google.com/github/Luke-687/Portfolio/blob/main/Track_History_In_a_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Include data points for record in 1980-2020 (5 year increments)

import matplotlib.pyplot as plt

#100
y100 = [1, 1, 0.998, 0.998, 0.991, 0.994, 0.996, 0.998, 0.991, 0.99, 0.992,0.994, 0.984,0.991,0.985,0.983, 0.989, 0.982, 0.984, 0.984, 0.977, 0.984, 0.980, 0.987, 0.991, 0.975, 0.975, 0.972, 0.967, 0.956, 0.954, 0.976, 0.974, 0.961, 0.975, 0.975, 0.972, 0.978, 0.980, 0.977, 0.974, 0.984, 0.974, 0.974, 0.981, 0.975]
x100 = [1979,1980,1981,1982,1983,1984,1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
def show100():
  plt.plot(x100, y100, color = 'green', linestyle='--', label="100m")

#200
y200 = [1, 1.01494, 1.01266, 1.01013, 1, 0.99848, 1.02025, 1, 1, 1, 0.99696, 0.99848, 0.99342, 1.00506, 0.99620, 1.00203, 1.00456, 0.99595, 0.99595, 0.99595, 1.00101, 0.99595, 1.00101, 1, 1.00051, 1.00101, 1.00253, 1.00354, 0.97721, 0.97139, 0.98228, 0.97139, 0.97873, 0.98861, 0.99089, 0.98987, 1.00152, 0.99494, 0.99494, 0.99089, 0.99848, 0.98962, 0.98101, 0.98228, 0.98734]
x200 = list(range(1980,2025))
def show200():
  plt.plot(x200,y200, color='orange', linestyle='--', label='200m')

#400
y400 = [1.0000, 0.9978, 0.9933, 0.9910, 0.9934, 0.9892, 0.9865, 0.9839, 0.9709, 0.9740, 0.9837, 0.9807, 0.9740, 0.9778, 0.9821, 0.9798, 0.9753, 0.9773, 0.9740, 0.9686, 0.9830, 0.9866, 0.9912, 0.9966, 0.9946, 0.9933, 0.9933, 0.9955, 0.9805, 0.9742, 0.9887, 0.9856, 0.9851, 0.9896, 0.9910, 0.9751, 0.9648, 0.9855, 0.9910, 0.9946, 0.9910, 0.9973, 0.9910, 0.9856, 0.9883]
x400 = list(range(1980,2025))
def show400():
  plt.plot(x400,y400, color = 'black', linestyle = '--', label='400m')

#800
y800 = [1.00000, 0.97339, 0.99923, 0.99142, 0.97424, 0.98060, 0.98713, 0.98607, 0.98201, 0.98605, 0.98563, 0.98696, 0.98303, 0.99130, 0.98619, 0.98433, 0.97471, 0.96808, 0.98305, 0.97838, 0.98615, 0.98100, 0.97909, 0.98076, 0.98619, 0.99271, 0.98626, 0.99278, 0.98241, 0.97599, 0.96672, 0.96956, 0.96737, 0.97967, 0.98039, 0.97735, 0.98617, 0.98295, 0.97610, 0.97442, 0.99854, 0.98561, 0.98855, 0.98561, 0.96808, 0.96737]
x800 = list(range(1980,2026))
def show800():
  plt.plot(x800,y800, color = 'purple', linestyle = '--', label='800m')

#1500
y1500 = [1, 1.00158, 1.00975, 0.99330, 1.00097, 0.98971, 0.99396, 0.99800, 1.00104, 0.99613, 1.01229, 0.99820, 0.98733, 0.99148, 0.99977, 0.97915, 0.99304, 0.99123, 0.97424, 0.98088, 0.97839, 0.97614, 0.97954, 0.98975, 0.98038, 0.99654, 0.99398, 0.99580, 1.00215, 0.99294, 0.99398, 1.00234, 0.99120, 0.98259, 0.98092, 0.97958, 0.99456, 0.99100, 0.98962, 0.99166, 0.98982, 0.98848, 0.99398, 0.97822, 0.97665]
x1500 = list(range(1980,2025))
def show1500():
  plt.plot(x1500,y1500, color='blue', linestyle = '--', label='1500m')

# %%
show100()
show200()
show400()
show800()
show1500()
plt.legend()
